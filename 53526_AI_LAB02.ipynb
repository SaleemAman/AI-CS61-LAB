# %%
# Initial list of cars
cars = ["BMW", "Audi", "Toyota", "Ford", "Honda"]
print("Initial cars list:", cars)
# Out:
# Initial cars list: ['BMW', 'Audi', 'Toyota', 'Ford', 'Honda']

# %%
cars.append("Mercedes")
print("After append():", cars)
# Out:
# After append(): ['BMW', 'Audi', 'Toyota', 'Ford', 'Honda', 'Mercedes']

# %%
temp_cars = cars.copy()   # copy used to keep original list safe
temp_cars.clear()
print("After clear():", temp_cars)
# Out:
# After clear(): []

# %%
cars_copy = cars.copy()
print("Copied list:", cars_copy)
# Out:
# Copied list: ['BMW', 'Audi', 'Toyota', 'Ford', 'Honda', 'Mercedes']

# %%
cars.append("Audi")
print("Cars list:", cars)
print("Count of 'Audi':", cars.count("Audi"))
# Out:
# Cars list: ['BMW', 'Audi', 'Toyota', 'Ford', 'Honda', 'Mercedes', 'Audi']
# Count of 'Audi': 2

# %%
more_cars = ["Hyundai", "Kia"]
cars.extend(more_cars)
print("After extend():", cars)
# Out:
# After extend(): ['BMW', 'Audi', 'Toyota', 'Ford', 'Honda', 'Mercedes', 'Audi', 'Hyundai', 'Kia']

# %%
cars.insert(2, "Tesla")
print("After insert():", cars)
# Out:
# After insert(): ['BMW', 'Audi', 'Tesla', 'Toyota', 'Ford', 'Honda', 'Mercedes', 'Audi', 'Hyundai', 'Kia']

# %%
removed_car = cars.pop(3)
print("Popped car:", removed_car)
print("After pop():", cars)
# Out:
# Popped car: Toyota
# After pop(): ['BMW', 'Audi', 'Tesla', 'Ford', 'Honda', 'Mercedes', 'Audi', 'Hyundai', 'Kia']

# %%
cars.remove("Ford")
print("After remove('Ford'):", cars)
# Out:
# After remove('Ford'): ['BMW', 'Audi', 'Tesla', 'Honda', 'Mercedes', 'Audi', 'Hyundai', 'Kia']

# %%
cars.reverse()
print("After reverse():", cars)
# Out:
# After reverse(): ['Kia', 'Hyundai', 'Audi', 'Mercedes', 'Honda', 'Tesla', 'Audi', 'BMW']

# %%
cars.sort()
print("After sort():", cars)
# Out:
# After sort(): ['Audi', 'Audi', 'BMW', 'Honda', 'Hyundai', 'Kia', 'Mercedes', 'Tesla']

# %%
# GPA Calculator using Lists, Loop and If-Else

subjects = ["OOP", "DB", "Pak St.", "English"]
credits = [4, 3, 2, 2]

total_points = 0
total_credits = 0

for i in range(len(subjects)):
    marks = int(input("Enter marks for " + subjects[i] + ": "))

    if marks >= 85:
        gp = 4.0
    elif marks >= 75:
        gp = 3.5
    elif marks >= 65:
        gp = 3.0
    elif marks >= 55:
        gp = 2.5
    else:
        gp = 2.0

    total_points += gp * credits[i]
    total_credits += credits[i]

gpa = total_points / total_credits
print("Your GPA is:", round(gpa, 2))
# Out:
# Enter marks for OOP: 90
# Enter marks for DB: 99
# Enter marks for Pak St.: 98
# Enter marks for English: 45
# Your GPA is: 3.64
